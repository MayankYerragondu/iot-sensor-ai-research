# %% [markdown]
# # PIR Model Evaluation Notebook
#
# This notebook evaluates PIR anomaly detection models.
#
# ## Steps:
# 1. Load test dataset (from S3 or local).
# 2. Load trained models (IF, GMM, OC-SVM).
# 3. Compute Precision, Recall, F1, and FAR.
# 4. Visualize results.
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# metrics = pd.read_csv("../results/pir_metrics.csv")
# metrics

# %% [markdown]
# metrics.plot(x="model", y=["precision","recall","f1"], kind="bar", figsize=(8,5))
# plt.title("PIR Model Performance")
# plt.show()

# %% [markdown]
# ---
#
# ✅ This setup gives you:
# - Automated evaluation (`evaluate_models.py`)
# - Visual reports (`metrics_visualization.py`)
# - Human-readable notebooks (`notebooks/`)
# - Persistent CSV results (`results/`)
#
# ---
#
# Would you like me to also add a **GitHub Actions workflow** (`.github/workflows/evaluation.yml`) so that every new commit automatically runs evaluations and uploads plots/metrics as build artifacts? That would make your repo super active.
